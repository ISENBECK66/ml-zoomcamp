# %%
import numpy as np
import pandas as pd

# %%
a=np.array([5,3,2,1])
a
# Out:
# array([5, 3, 2, 1])

# %%
b=np.array([2,3,5,0])
b
# Out:
# array([2, 3, 5, 0])

# %%
b.shape[0]
# Out:
# 4

# %%
C=np.array([[2,4,5,6],
          [1,2,1,2],
          [3,1,2,1]])
C
# Out:
# array([[2, 4, 5, 6],
#        [1, 2, 1, 2],
#        [3, 1, 2, 1]])

# %%
C.shape[0]
# Out:
# 3

# %%
d=np.array([1,2,3,4])
d
# Out:
# array([1, 2, 3, 4])

# %%
d.shape[0]
# Out:
# 4

# %%
def vector_vector_multiplication(u,v):
    
    assert u.shape[0] == v.shape[0]
    
    n=u.shape[0]
    result = 0.0
    
    for i in range (n):
    
        result=result+u[i]*v[i]
    
    return result

# %%
vector_vector_multiplication(a,b)
# Out:
# 29.0

# %%
def matrix_vector_multiplication(U,v):
    
    assert U.shape[1] == v.shape[0]
    
    num_rows=U.shape[0]
    
    result = np.ones(num_rows)
    
    for i in range (num_rows):
        result[i]=vector_vector_multiplication(U[i],v)
        
    return result

# %%
matrix_vector_multiplication(C,d)
# Out:
# array([49., 16., 15.])

# %%
C.dot(d)
# Out:
# array([49, 16, 15])

# %%
a.dot(b)
# Out:
# 29

# %%
E=np.array([[1,1,2],[0,0.5,1],[0,2,1],[2,1,0]])
E
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %%
array_bi=np.ones((3,4))
array_bi[1]
# Out:
# array([1., 1., 1., 1.])

# %%
def matrix_matrix_multiplication(U,V):
    assert U.shape[1]==V.shape[0]
    
    num_row=U.shape[0]
    num_cols=V.shape[1]
    
    result=np.zeros((num_row,num_cols))
    
    for i in range(num_cols):
        vi=V[:,i]
        Uvi= matrix_vector_multiplication(U,vi)
        result[:,i]=Uvi
    return result

# %%
matrix_matrix_multiplication(C,E)
# Out:
# array([[14. , 20. , 13. ],
#        [ 5. ,  6. ,  5. ],
#        [ 5. ,  8.5,  9. ]])

# %%
C.dot(E)
# Out:
# array([[14. , 20. , 13. ],
#        [ 5. ,  6. ,  5. ],
#        [ 5. ,  8.5,  9. ]])

# %%
I=np.eye(3)
I
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
E
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %%
E.dot(I)
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %%
Es = E[[0,1,2]]
Es
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ]])

# %%
Esinv = np.linalg.inv(Es)
Esinv
# Out:
# array([[ 1.        , -2.        ,  0.        ],
#        [ 0.        , -0.66666667,  0.66666667],
#        [ 0.        ,  1.33333333, -0.33333333]])

# %%
Esinv.dot(Es)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
data =[ 
['Nissan','Stanza', 1991, 138, 4, 'MANUAL', 'sedan', 2000],
['Hyundai', 'Sonata', 2017, None, 4, 'AUTOMATIC', 'Sedan', 27150],    
['Lotus', 'Elise', 2010, 218, 4, 'MANUAL', 'convertible', 54990],
['GMC', 'Acadia', 2017, 194, 4, 'AUTOMATIC', '4dr SUV', 34450],
['Nissan', 'Frontier', 2017, 261, 6, 'MANUAL', 'Pickup', 32340]
]

columns = [
    'Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders', 'Transmission Type', 'Vehicle_Style', 'MSRP'
]

# %%
df=pd.DataFrame(data, columns=columns)
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df.head(2)
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan  Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150

# %%
df.Make
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %%
df['Make']
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %%
df[['Make', 'Model']]
# Out:
#       Make     Model
# 0   Nissan    Stanza
# 1  Hyundai    Sonata
# 2    Lotus     Elise
# 3      GMC    Acadia
# 4   Nissan  Frontier

# %%
df['id']=[ 1, 2, 3, 4, 5]

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP  id
# 0         sedan   2000   1
# 1         Sedan  27150   2
# 2   convertible  54990   3
# 3       4dr SUV  34450   4
# 4        Pickup  32340   5

# %%
df['id']=[ 10, 20, 30, 40, 50]
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP  id
# 0         sedan   2000  10
# 1         Sedan  27150  20
# 2   convertible  54990  30
# 3       4dr SUV  34450  40
# 4        Pickup  32340  50

# %%
del df['id']

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.Make
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %%
df.Make.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.loc[1]
# Out:
# Make                   Hyundai
# Model                   Sonata
# Year                      2017
# Engine HP                  NaN
# Engine Cylinders             4
# Transmission Type    AUTOMATIC
# Vehicle_Style            Sedan
# MSRP                     27150
# Name: 1, dtype: object

# %%
df.loc[[1,2]]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 1  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus   Elise  2010      218.0                 4            MANUAL
#
#   Vehicle_Style   MSRP
# 1         Sedan  27150
# 2   convertible  54990

# %%
df.index=['a','b','c','d','e']

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a   Nissan    Stanza  1991      138.0                 4            MANUAL
# b  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus     Elise  2010      218.0                 4            MANUAL
# d      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# e   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         Sedan  27150
# c   convertible  54990
# d       4dr SUV  34450
# e        Pickup  32340

# %%
df.loc[[1,2]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3550/3267477224.py in <module>
# ----> 1 df.loc[[1,2]]
#
# ~/anaconda3/envs/ml-zoomcamp/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/anaconda3/envs/ml-zoomcamp/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ...

# %%
df.loc[['a','b']]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a   Nissan  Stanza  1991      138.0                 4            MANUAL
# b  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         Sedan  27150

# %%
df.iloc[[1,2]]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# b  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus   Elise  2010      218.0                 4            MANUAL
#
#   Vehicle_Style   MSRP
# b         Sedan  27150
# c   convertible  54990

# %%
df.reset_index()
# Out:
#   index     Make     Model  Year  Engine HP  Engine Cylinders  \
# 0     a   Nissan    Stanza  1991      138.0                 4
# 1     b  Hyundai    Sonata  2017        NaN                 4
# 2     c    Lotus     Elise  2010      218.0                 4
# 3     d      GMC    Acadia  2017      194.0                 4
# 4     e   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 0            MANUAL         sedan   2000
# 1         AUTOMATIC         Sedan  27150
# 2            MANUAL   convertible  54990
# 3         AUTOMATIC       4dr SUV  34450
# 4            MANUAL        Pickup  32340

# %%
df=df.reset_index(drop=True)

# %%
df

# %%
df['Engine HP']/100

# %%
df

# %%
df['Year']>2015

# %%
df[df['Year']>2015]

# %%
df[df['Make']== 'Nissan']

# %%
df

# %%
df[
    (df['Make']== 'Nissan')& (df['Year']>2015)
]

# %%
df['Vehicle_Style']

# %%
df

# %%
'STR'.lower()
# Out:
# 'str'

# %%
df['Vehicle_Style'].str.lower()
# Out:
# a          sedan
# b          sedan
# c    convertible
# d        4dr suv
# e         pickup
# Name: Vehicle_Style, dtype: object

# %%
'machine learning zoomcamp'.replace(' ','_')
# Out:
# 'machine_learning_zoomcamp'

# %%
df['Vehicle_Style'].str.replace(' ','_').str.lower()
# Out:
# a          sedan
# b          sedan
# c    convertible
# d        4dr_suv
# e         pickup
# Name: Vehicle_Style, dtype: object

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a   Nissan    Stanza  1991      138.0                 4            MANUAL
# b  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus     Elise  2010      218.0                 4            MANUAL
# d      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# e   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         Sedan  27150
# c   convertible  54990
# d       4dr SUV  34450
# e        Pickup  32340

# %%
df['Vehicle_Style']=df['Vehicle_Style'].str.replace(' ','_').str.lower()

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a   Nissan    Stanza  1991      138.0                 4            MANUAL
# b  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus     Elise  2010      218.0                 4            MANUAL
# d      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# e   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         sedan  27150
# c   convertible  54990
# d       4dr_suv  34450
# e        pickup  32340

# %%
df.MSRP
# Out:
# a     2000
# b    27150
# c    54990
# d    34450
# e    32340
# Name: MSRP, dtype: int64

# %%
df.MSRP.min()
# Out:
# 2000

# %%
df.MSRP.mean()
# Out:
# 30186.0

# %%
df.MSRP.describe()
# Out:
# count        5.000000
# mean     30186.000000
# std      18985.044904
# min       2000.000000
# 25%      27150.000000
# 50%      32340.000000
# 75%      34450.000000
# max      54990.000000
# Name: MSRP, dtype: float64

# %%
df.describe()
# Out:
#               Year  Engine HP  Engine Cylinders          MSRP
# count     5.000000    4.00000          5.000000      5.000000
# mean   2010.400000  202.75000          4.400000  30186.000000
# std      11.260551   51.29896          0.894427  18985.044904
# min    1991.000000  138.00000          4.000000   2000.000000
# 25%    2010.000000  180.00000          4.000000  27150.000000
# 50%    2017.000000  206.00000          4.000000  32340.000000
# 75%    2017.000000  228.75000          4.000000  34450.000000
# max    2017.000000  261.00000          6.000000  54990.000000

# %%
df.describe().round(2)
# Out:
#           Year  Engine HP  Engine Cylinders      MSRP
# count     5.00       4.00              5.00      5.00
# mean   2010.40     202.75              4.40  30186.00
# std      11.26      51.30              0.89  18985.04
# min    1991.00     138.00              4.00   2000.00
# 25%    2010.00     180.00              4.00  27150.00
# 50%    2017.00     206.00              4.00  32340.00
# 75%    2017.00     228.75              4.00  34450.00
# max    2017.00     261.00              6.00  54990.00

# %%
df.Make
# Out:
# a     Nissan
# b    Hyundai
# c      Lotus
# d        GMC
# e     Nissan
# Name: Make, dtype: object

# %%
df.Make.nunique()
# Out:
# 4

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a   Nissan    Stanza  1991      138.0                 4            MANUAL
# b  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus     Elise  2010      218.0                 4            MANUAL
# d      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# e   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         sedan  27150
# c   convertible  54990
# d       4dr_suv  34450
# e        pickup  32340

# %%
df.nunique()
# Out:
# Make                 4
# Model                5
# Year                 3
# Engine HP            4
# Engine Cylinders     2
# Transmission Type    2
# Vehicle_Style        4
# MSRP                 5
# dtype: int64

# %%
df.isnull()
# Out:
#     Make  Model   Year  Engine HP  Engine Cylinders  Transmission Type  \
# a  False  False  False      False             False              False
# b  False  False  False       True             False              False
# c  False  False  False      False             False              False
# d  False  False  False      False             False              False
# e  False  False  False      False             False              False
#
#    Vehicle_Style   MSRP
# a          False  False
# b          False  False
# c          False  False
# d          False  False
# e          False  False

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine HP            1
# Engine Cylinders     0
# Transmission Type    0
# Vehicle_Style        0
# MSRP                 0
# dtype: int64

# %%
df.groupby('Transmission Type').MSRP.mean()
# Out:
# Transmission Type
# AUTOMATIC    30800.000000
# MANUAL       29776.666667
# Name: MSRP, dtype: float64

# %%
df.groupby('Transmission Type').MSRP.max()
# Out:
# Transmission Type
# AUTOMATIC    34450
# MANUAL       54990
# Name: MSRP, dtype: int64

# %%
df.MSRP
# Out:
# a     2000
# b    27150
# c    54990
# d    34450
# e    32340
# Name: MSRP, dtype: int64

# %%
df.MSRP.values
# Out:
# array([ 2000, 27150, 54990, 34450, 32340])

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a   Nissan    Stanza  1991      138.0                 4            MANUAL
# b  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus     Elise  2010      218.0                 4            MANUAL
# d      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# e   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         sedan  27150
# c   convertible  54990
# d       4dr_suv  34450
# e        pickup  32340

# %%
df.to_dict(orient='records')

# %%
data1=[{'Make': 'Nissan1',
  'Model': 'Stanza',
  'Year': 1991,
  'Engine HP': 138.0,
  'Engine Cylinders': 4,
  'Transmission Type': 'MANUAL',
  'Vehicle_Style': 'sedan',
  'MSRP': 2000},
 {'Make': 'Hyundai',
  'Model': 'Sonata',
  'Year': 2017,
  'Engine HP': None,
  'Engine Cylinders': 4,
  'Transmission Type': 'AUTOMATIC',
  'Vehicle_Style': 'sedan',
  'MSRP': 27150},
 {'Make': 'Lotus',
  'Model': 'Elise',
  'Year': 2010,
  'Engine HP': 218.0,
  'Engine Cylinders': 4,
  'Transmission Type': 'MANUAL',
  'Vehicle_Style': 'convertible',
  'MSRP': 54990},
 {'Make': 'GMC',
  'Model': 'Acadia',
  'Year': 2017,
  'Engine HP': 194.0,
  'Engine Cylinders': 4,
  'Transmission Type': 'AUTOMATIC',
  'Vehicle_Style': '4dr_suv',
  'MSRP': 34450},
 {'Make': 'Nissan',
  'Model': 'Frontier',
  'Year': 2017,
  'Engine HP': 261.0,
  'Engine Cylinders': 6,
  'Transmission Type': 'MANUAL',
  'Vehicle_Style': 'pickup',
  'MSRP': 32340}]

# %%
df1=pd.DataFrame(data1)

# %%
df1

# %%
np.__version__
# Out:
# '1.20.3'

# %%
pd.__version__
# Out:
# '1.3.2'

# %%
hw = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv')

# %%
hw
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
hw.groupby('Make').MSRP.mean()
# Out:
# Make
# Acura            3.488759e+04
# Alfa Romeo       6.160000e+04
# Aston Martin     1.979104e+05
# Audi             5.345211e+04
# BMW              6.154676e+04
# Bentley          2.471693e+05
# Bugatti          1.757224e+06
# Buick            2.820661e+04
# Cadillac         5.623132e+04
# Chevrolet        2.835039e+04
# Chrysler         2.672296e+04
# Dodge            2.239006e+04
# FIAT             2.267024e+04
# Ferrari          2.382188e+05
# Ford             2.739927e+04
# GMC              3.049330e+04
# Genesis          4.661667e+04
# HUMMER           3.646441e+04
# Honda            2.667434e+04
# Hyundai          2.459704e+04
# Infiniti         4.239421e+04
# Kia              2.531017e+04
# Lamborghini      3.315673e+05
# Land Rover       6.782322e+04
# Lexus            4.754907e+04
# Lincoln          4.283983e+04
# Lotus            6.918828e+04
# Maserati         1.142077e+05
# Maybach          5.462219e+05
# Mazda            2.003938e+04
# McLaren          2.398050e+05
# ...

# %%
bmw = hw [hw.Make=='BMW']

# %%
bmw
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 2      BMW    1 Series  2011  premium unleaded (required)      300.0
# 3      BMW    1 Series  2011  premium unleaded (required)      230.0
# 4      BMW    1 Series  2011  premium unleaded (required)      230.0
# ...    ...         ...   ...                          ...        ...
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
bmw.groupby('Make').MSRP.mean()
# Out:
# Make
# BMW    61546.763473
# Name: MSRP, dtype: float64

# %%
hw [hw.Make=='BMW'].groupby('Make').MSRP.mean()
# Out:
# Make
# BMW    61546.763473
# Name: MSRP, dtype: float64

# %%
hw [hw.Year>=2015].isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP              51
# Engine Cylinders        8
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         5
# Market Category      1324
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
hw['Engine HP'].mean()
# Out:
# 249.38607007176023

# %%
hw['Make']
# Out:
# 0            BMW
# 1            BMW
# 2            BMW
# 3            BMW
# 4            BMW
#           ...
# 11909      Acura
# 11910      Acura
# 11911      Acura
# 11912      Acura
# 11913    Lincoln
# Name: Make, Length: 11914, dtype: object

# %%
hw.Make
# Out:
# 0            BMW
# 1            BMW
# 2            BMW
# 3            BMW
# 4            BMW
#           ...
# 11909      Acura
# 11910      Acura
# 11911      Acura
# 11912      Acura
# 11913    Lincoln
# Name: Make, Length: 11914, dtype: object

# %%
hw['Engine HP']
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: Engine HP, Length: 11914, dtype: float64

# %%
hw['Engine HP'].mean()
# Out:
# 249.38607007176023

# %%
hw['Engine HP'].fillna(value=(hw['Engine HP'].mean())).mean()
# Out:
# 249.38607007176

# %%
hwroll = hw [hw.Make=='Rolls-Royce']

# %%
hw
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
X = np.array(hwroll [['Engine HP', 'Engine Cylinders', 'highway MPG']].drop_duplicates().values)

# %%
X
# Out:
# array([[325.,   8.,  15.],
#        [563.,  12.,  19.],
#        [563.,  12.,  21.],
#        [563.,  12.,  20.],
#        [322.,  12.,  15.],
#        [453.,  12.,  19.],
#        [624.,  12.,  21.]])

# %%
T=X.T

# %%
T
# Out:
# array([[325., 563., 563., 563., 322., 453., 624.],
#        [  8.,  12.,  12.,  12.,  12.,  12.,  12.],
#        [ 15.,  19.,  21.,  20.,  15.,  19.,  21.]])

# %%
XTX = X.dot(T)

# %%
np.linalg.inv(XTX)
# Out:
# array([[-6.73927593e+10, -1.81692802e+11,  7.48785308e+10,
#         -3.18528662e+10,  6.36937052e+10, -2.71582602e+10,
#          1.47060199e+11],
#        [-6.29137427e+10, -2.05634126e+11,  1.53090219e+11,
#         -7.07084718e+10,  1.07044261e+11, -1.11601294e+11,
#          1.69751906e+11],
#        [ 1.73029720e+10,  1.58501310e+11, -1.59603900e+11,
#          4.24365432e+10, -1.19226079e+11,  1.86610143e+11,
#         -1.20253331e+11],
#        [-4.14754837e+10, -1.11886658e+11,  1.77535361e+11,
#         -3.31586119e+09,  7.53459959e+10, -1.33231141e+11,
#          2.32026254e+10],
#        [-1.37567757e+10,  1.40321201e+10, -8.39304153e+10,
#          2.28709419e+10, -4.57426423e+10,  1.04881948e+11,
#         -2.94076866e+09],
#        [ 9.12254321e+10,  1.28634694e+11,  4.73726118e+10,
#         -1.21728564e+10,  2.43575203e+10, -1.50008110e+11,
#         -9.90008138e+10],
#        [ 5.45461043e+10,  1.37481195e+11, -1.84382897e+11,
# ...

# %%
np.sum(np.linalg.inv(XTX))
# Out:
# -7488084371.210449

# %%
seven=np.array([1000, 1100, 900, 1200, 1000, 850, 1300])

# %%
seven
# Out:
# array([1000, 1100,  900, 1200, 1000,  850, 1300])

# %%
XTX = matrix_matrix_multiplication (T, X)

# %%
XTX
# Out:
# array([[1.754801e+06, 3.965600e+04, 6.519600e+04],
#        [3.965600e+04, 9.280000e+02, 1.500000e+03],
#        [6.519600e+04, 1.500000e+03, 2.454000e+03]])

# %%
XTXinv = np.linalg.inv(XTX)

# %%
np.sum(XTXinv)
# Out:
# 0.03221232067748617

# %%
RIS = matrix_matrix_multiplication(XTXinv,(X.T))

# %%
y = np.array ([1000, 1100, 900, 1200, 1000, 850, 1300])

# %%
w = matrix_vector_multiplication(RIS, y)

# %%
w
# Out:
# array([ 0.19989598, 31.02612262, 31.65378877])
